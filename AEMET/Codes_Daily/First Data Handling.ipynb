# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DF = pd.read_csv('~/Rn_Weekly_NN/AEMET/Data/Daily/BCN_ZGZ_PMP_Daily2012-2018.csv', usecols=range(1, 8))
DF.head()
# Out:
#   indicativo       fecha  tmed   dir  velmedia  presMax  presMin
# 0       9434  2017-01-01   2.0  12.0       1.7   1000.8    993.0
# 1       9434  2017-01-02   1.0  30.0       2.2    995.1    992.7
# 2       9434  2017-01-03   4.0  24.0       2.8    995.0    992.6
# 3       9434  2017-01-04   6.5  28.0       5.6    995.4    991.9
# 4       9434  2017-01-05   7.8  30.0      10.8    996.8    991.6

# %%
DF.describe()
# Out:
#                tmed          dir      velmedia       presMax       presMin
# count  10174.000000  9925.000000  10177.000000  10177.000000  10176.000000
# mean      15.520012    38.746599      4.081321    982.969166    978.179766
# std        7.125933    31.699080      2.328587     24.944659     25.083108
# min       -3.400000     1.000000      0.000000    931.300000    918.000000
# 25%        9.800000    20.000000      2.500000    961.200000    956.400000
# 50%       15.200000    29.000000      3.600000    979.200000    974.000000
# 75%       21.400000    35.000000      5.300000   1003.800000    998.600000
# max       33.800000    99.000000     16.100000   1040.900000   1035.900000

# %%
print('How many nulls has the dataframe?', DF.isnull().sum())
# Out:
# How many nulls has the dataframe? indicativo      0
# fecha           0
# tmed           58
# dir           307
# velmedia       55
# presMax        55
# presMin        56
# dtype: int64

# %%
DF[DF['tmed'].isnull()]['tmed']
# Out:
# 894    NaN
# 1183   NaN
# 1219   NaN
# 1220   NaN
# 1221   NaN
# 1222   NaN
# 1223   NaN
# 1224   NaN
# 1225   NaN
# 1226   NaN
# 1227   NaN
# 1228   NaN
# 1229   NaN
# 1230   NaN
# 1231   NaN
# 1232   NaN
# 1233   NaN
# 1234   NaN
# 1235   NaN
# 1236   NaN
# 1237   NaN
# 1238   NaN
# 1239   NaN
# 1240   NaN
# 1241   NaN
# 1242   NaN
# 1243   NaN
# 1244   NaN
# 1245   NaN
# 1246   NaN
# 2141   NaN
# 2142   NaN
# 2146   NaN
# 2159   NaN
# 3609   NaN
# 4046   NaN
# 4092   NaN
# 4162   NaN
# 4370   NaN
# 5570   NaN
# 5624   NaN
# 5638   NaN
# 5663   NaN
# 6130   NaN
# 6131   NaN
# 6138   NaN
# 6152   NaN
# 8111   NaN
# 8135   NaN
# 8601   NaN
# 8612   NaN
# 8619   NaN
# 8665   NaN
# 8666   NaN
# 8703   NaN
# 8704   NaN
# 8970   NaN
# 9644   NaN
# Name: tmed, dtype: float64

# %%
DF.plot(x='fecha', y='tmed', style=':', figsize=(10, 8))
plt.ylabel('Average Temperature', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5, 0, 'Date')

# %%
DF.plot(x='fecha', y='velmedia', style=':', figsize=(10, 8))
plt.ylabel('Average Wind Velocity', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5, 0, 'Date')

# %%
DF.plot(x='fecha', y='presMax', style=':', figsize=(10, 8))
plt.ylabel('Maximum Preassure', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5, 0, 'Date')

# %%
DF.plot(x='fecha', y='presMin', style=':', figsize=(10, 8))
plt.ylabel('Minimun Preassure', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5, 0, 'Date')
