# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DF = pd.read_csv('~/Rn_Weekly_NN/AEMET/Data/Daily/BCN_ZGZ_PMP_Daily2012-2018.csv', usecols=range(1, 8))
DF.head()
# Out:
#   indicativo       fecha  tmed   dir  velmedia  presMax  presMin
# 0       0076  2012-01-01  12.9  99.0       4.4   1025.9   1020.4
# 1       0076  2012-01-02  12.6  26.0       3.6   1027.2   1018.0
# 2       0076  2012-01-03  10.6  35.0       2.8   1030.5   1027.0
# 3       0076  2012-01-04  10.8  30.0       4.7   1029.1   1025.7
# 4       0076  2012-01-05  11.3  31.0       3.1   1028.3   1013.5

# %%
DF.describe()
# Out:
#               tmed          dir     velmedia      presMax      presMin
# count  7592.000000  7597.000000  7617.000000  7615.000000  7614.000000
# mean     15.776264    42.797157     4.224209   992.206513   987.260665
# std       7.003093    33.404928     2.258385    21.736376    22.133635
# min      -3.400000     1.000000     0.000000   940.000000   925.300000
# 25%      10.200000    22.000000     2.800000   971.900000   967.600000
# 50%      15.400000    31.000000     3.900000   989.600000   984.800000
# 75%      21.600000    36.000000     5.300000  1015.200000  1010.100000
# max      33.800000    99.000000    15.300000  1040.900000  1035.900000

# %%
print('How many nulls has the dataframe?', DF.isnull().sum())
# Out:
# How many nulls has the dataframe? indicativo     0
# fecha          0
# tmed          58
# dir           53
# velmedia      33
# presMax       35
# presMin       36
# dtype: int64

# %%
DF[DF['tmed'].isnull()]['tmed']
# Out:
# 68     NaN
# 92     NaN
# 507    NaN
# 2132   NaN
# 2133   NaN
# 2137   NaN
# 2150   NaN
# 2209   NaN
# 2255   NaN
# 2325   NaN
# 2533   NaN
# 2746   NaN
# 4323   NaN
# 5014   NaN
# 5015   NaN
# 5022   NaN
# 5036   NaN
# 5291   NaN
# 5302   NaN
# 5309   NaN
# 5355   NaN
# 5356   NaN
# 5393   NaN
# 5394   NaN
# 5914   NaN
# 5968   NaN
# 5982   NaN
# 6007   NaN
# 6354   NaN
# 7005   NaN
# 7041   NaN
# 7042   NaN
# 7043   NaN
# 7044   NaN
# 7045   NaN
# 7046   NaN
# 7047   NaN
# 7048   NaN
# 7049   NaN
# 7050   NaN
# 7051   NaN
# 7052   NaN
# 7053   NaN
# 7054   NaN
# 7055   NaN
# 7056   NaN
# 7057   NaN
# 7058   NaN
# 7059   NaN
# 7060   NaN
# 7061   NaN
# 7062   NaN
# 7063   NaN
# 7064   NaN
# 7065   NaN
# 7066   NaN
# 7067   NaN
# 7068   NaN
# Name: tmed, dtype: float64

# %%
DF.plot(x='fecha', y='tmed', style='o', figsize=(10, 8))
plt.ylabel('Average Temperature', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5,0,'Date')

# %%
DF.plot(x='fecha', y='velmedia', style='o', figsize=(10, 8))
plt.ylabel('Average Wind Velocity', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5,0,'Date')

# %%
DF.plot(x='fecha', y='presMax', style='o', figsize=(10, 8))
plt.ylabel('Maximum Preassure', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5,0,'Date')

# %%
DF.plot(x='fecha', y='presMin', style='o', figsize=(10, 8))
plt.ylabel('Minimun Preassure', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5,0,'Date')
