# %%
import numpy as np
import pandas as pd
import urllib
import json
import requests
import matplotlib.pyplot as plt

# %%
from AEMET_Daily_class import AEMET_GET

# %%
# In this case you can download the data in intervals of 3 years
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018]
IDs = ['0076', '9263D', '9434'] 
names = ['BCN', 'PMP', 'ZGZ']
api_key='eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJ0c3NhbmNoZXpwYXN0b3JAZ21haWwuY29tIiwianRpIjoiYzQzZGM1ZmYtNmRiYS00MzFmLTk3OTEtZWMzNGE3YjUzMDI3IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE1NjY0Nzc2OTgsInVzZXJJZCI6ImM0M2RjNWZmLTZkYmEtNDMxZi05NzkxLWVjMzRhN2I1MzAyNyIsInJvbGUiOiIifQ.bjmGdiW9vQ2ThnrLryvCxv2tad8XRDXA9zlcBQRg-U4'

# %%
def Complete_Dictionary(names, years, IDs, fields):
    i = 0
    DIC = {}
    for ID in IDs:
        name = names[i]
        i += 1
        print('\n\nStation: '+ name)
        for year in years:
            print('Year: {}:'.format(year))
            A = AEMET_GET(year, year)
            js = A.connect(api_key, 'Data', ID)
            DIC[ID + str(year)] = A.get_DF(fields, js)
    return DIC

# %%
fields = ['indicativo', 'fecha', 'tmed', 'dir', 'velmedia', 'presMax', 'presMin']
DIC = Complete_Dictionary(names, years, IDs, fields)
# Out:
# Station: BCN
# Year: 2012:
#
#  You are going to Download the data from 2012 to 2012
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a6416e7e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2013:
#
#  You are going to Download the data from 2013 to 2013
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b7690312",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2014:
#
#  You are going to Download the data from 2014 to 2014
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/14a9a5d6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2015:
#
#  You are going to Download the data from 2015 to 2015
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c71399e6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2016:
#
#  You are going to Download the data from 2016 to 2016
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f54a2ea6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2017:
#
#  You are going to Download the data from 2017 to 2017
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/21857e3a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2018:
#
#  You are going to Download the data from 2018 to 2018
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/7c7d4d93",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
#
#
# Station: PMP
# Year: 2012:
#
#  You are going to Download the data from 2012 to 2012
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5bb11c01",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2013:
#
#  You are going to Download the data from 2013 to 2013
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2c053f8a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2014:
#
#  You are going to Download the data from 2014 to 2014
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/3eefc638",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2015:
#
#  You are going to Download the data from 2015 to 2015
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f23b3fa5",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2016:
#
#  You are going to Download the data from 2016 to 2016
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/086cc146",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2017:
#
#  You are going to Download the data from 2017 to 2017
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/73ccf3a2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2018:
#
#  You are going to Download the data from 2018 to 2018
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/385c4f80",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
#
#
# Station: ZGZ
# Year: 2012:
#
#  You are going to Download the data from 2012 to 2012
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/195828b9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2013:
#
#  You are going to Download the data from 2013 to 2013
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ddc35a60",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2014:
#
#  You are going to Download the data from 2014 to 2014
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/36102a10",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2015:
#
#  You are going to Download the data from 2015 to 2015
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a630b0ca",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2016:
#
#  You are going to Download the data from 2016 to 2016
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e6cf80ca",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2017:
#
#  You are going to Download the data from 2017 to 2017
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e8c31081",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# Year: 2018:
#
#  You are going to Download the data from 2018 to 2018
# from the stations with IDs:
#
# 0076
# 9263D
# 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a55e1091",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }

# %%
def concat_dictionary(DIC):
    keys_list = [key for key in DIC.keys()]
    for j in range(len(keys_list)):
        if j == 0:
            Final = DIC[keys_list[0]]
        else:
            Final = pd.concat([Final, DIC[keys_list[j]]])
    return Final

# %%
Data = concat_dictionary(DIC)

# %%
Data
# Out:
#     indicativo       fecha  tmed   dir  velmedia  presMax  presMin
# 0         0076  2012-01-01  12.9  99.0       4.4   1025.9   1020.4
# 1         0076  2012-01-02  12.6  26.0       3.6   1027.2   1018.0
# 2         0076  2012-01-03  10.6  35.0       2.8   1030.5   1027.0
# 3         0076  2012-01-04  10.8  30.0       4.7   1029.1   1025.7
# 4         0076  2012-01-05  11.3  31.0       3.1   1028.3   1013.5
# 5         0076  2012-01-06  11.5  31.0       2.2   1026.3   1013.3
# 6         0076  2012-01-07   9.0  34.0       2.8   1029.4   1025.3
# 7         0076  2012-01-08   9.0  33.0       3.9   1027.6   1023.8
# 8         0076  2012-01-09  10.0  35.0       4.4   1031.2   1024.5
# 9         0076  2012-01-10   8.4  22.0       3.9   1031.7   1028.7
# 10        0076  2012-01-11   9.2  99.0       2.5   1033.4   1029.8
# 11        0076  2012-01-12   8.6  35.0       5.3   1032.2   1028.6
# 12        0076  2012-01-13   7.6  99.0       6.1   1028.6   1021.1
# 13        0076  2012-01-14   6.7  99.0       5.0   1021.1   1018.3
# 14        0076  2012-01-15   8.4  99.0       3.6   1018.9   1015.6
# 15        0076  2012-01-16   8.0  99.0       8.1   1020.5   1013.7
# 16        0076  2012-01-17  10.0  99.0       4.7   1030.8   1020.4
# 17        0076  2012-01-18   9.0  99.0       2.5   1035.5   1030.0
# 18        0076  2012-01-19   8.2  99.0       5.3   1036.4   1031.2
# 19        0076  2012-01-20  11.6  99.0       2.5   1031.3   1026.0
# 20        0076  2012-01-21  12.2  35.0       1.9   1026.6   1023.3
# 21        0076  2012-01-22  12.4  35.0       3.1   1023.4   1018.4
# 22        0076  2012-01-23  11.5  34.0       4.2   1019.3   1016.1
# 23        0076  2012-01-24  10.8  34.0       3.1   1023.0   1019.3
# 24        0076  2012-01-25   9.2  34.0       5.0   1022.4   1017.2
# 25        0076  2012-01-26   9.4  99.0       3.6   1019.7   1016.2
# 26        0076  2012-01-27   9.8  99.0       4.7   1023.6   1019.3
# 27        0076  2012-01-28   7.6   6.0       2.2   1024.6   1019.2
# 28        0076  2012-01-29   5.7  34.0       3.6   1019.4   1016.4
# 29        0076  2012-01-30   6.4  35.0       4.2   1022.7   1018.2
# ..         ...         ...   ...   ...       ...      ...      ...
# 335       9434  2012-12-01   5.0  30.0       9.2    988.0    978.2
# 336       9434  2012-12-02   7.0  30.0       8.3    994.2    988.0
# 337       9434  2012-12-03  10.6  28.0       5.6    996.3    991.8
# 338       9434  2012-12-04   8.0  33.0       7.2    991.8    987.7
# 339       9434  2012-12-05   7.8  30.0       5.3    989.1    985.6
# 340       9434  2012-12-06   7.5  25.0       3.1    990.4    986.8
# 341       9434  2012-12-07   6.4  28.0       3.6    986.9    982.5
# 342       9434  2012-12-08   8.8  31.0      10.0    995.4    986.9
# 343       9434  2012-12-09   6.8  29.0       5.0    996.0    992.6
# 344       9434  2012-12-10   5.6  29.0       9.4    992.6    987.5
# 345       9434  2012-12-11   7.0  30.0       5.3    989.7    988.2
# 346       9434  2012-12-12   1.6   9.0       1.7    988.9    984.6
# 347       9434  2012-12-13   4.1  12.0       3.3    984.6    980.1
# 348       9434  2012-12-14   7.6   8.0       3.3    981.2    976.5
# 349       9434  2012-12-15  12.4  99.0       3.6    987.7    978.1
# 350       9434  2012-12-16  14.2  24.0       4.2    989.8    985.7
# 351       9434  2012-12-17   9.8  27.0       4.2    992.2    986.9
# 352       9434  2012-12-18   7.7  99.0       2.5    992.6    990.4
# 353       9434  2012-12-19   9.8   7.0       1.7    991.4    986.9
# 354       9434  2012-12-20  12.5  28.0       4.4    988.2    985.2
# 355       9434  2012-12-21  12.8  30.0       3.6    992.2    984.9
# 356       9434  2012-12-22  10.9  25.0       1.1    993.5    991.6
# 357       9434  2012-12-23   8.6  27.0       0.8    994.0    990.0
# 358       9434  2012-12-24   8.2   8.0       2.5    990.0    984.2
# 359       9434  2012-12-25   7.5  99.0       2.8    987.6    981.8
# 360       9434  2012-12-26   9.3  29.0       6.9    997.7    987.6
# 361       9434  2012-12-27   7.0  27.0       3.1   1002.3    997.5
# 362       9434  2012-12-28  10.2  99.0       3.1   1001.9    997.9
# 363       9434  2012-12-29   6.6  25.0       2.8    997.9    991.5
# 364       9434  2012-12-30   7.0  28.0       3.9   1001.3    996.0
#
# [7650 rows x 7 columns]

# %%
Data.isnull().sum()
# Out:
# indicativo     0
# fecha          0
# tmed          58
# dir           53
# velmedia      33
# presMax       35
# presMin       36
# dtype: int64

# %%
assert len(Data['fecha'].unique()) == len(Data['fecha'])/3
print('No hay ningun dato repetido')
# Out:
# No hay ningun dato repetido

# %%
Data.to_csv('~/Rn_Weekly_NN/AEMET/Data/Daily/BCN_ZGZ_PMP_Daily' + str(years[0]) + '-' + str(years[-1]) + '.csv')
