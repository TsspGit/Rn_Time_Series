# %%
import numpy as np
import pandas as pd
import urllib
import json
import requests

# %%
from AEMET_class import AEMET_GET

# %%
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018]
IDs = ['0076', '9263D', '9434'] 
names = ['BCN', 'PMP', 'ZGZ']
api_key='eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJ0c3NhbmNoZXpwYXN0b3JAZ21haWwuY29tIiwianRpIjoiYzQzZGM1ZmYtNmRiYS00MzFmLTk3OTEtZWMzNGE3YjUzMDI3IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE1NjY0Nzc2OTgsInVzZXJJZCI6ImM0M2RjNWZmLTZkYmEtNDMxZi05NzkxLWVjMzRhN2I1MzAyNyIsInJvbGUiOiIifQ.bjmGdiW9vQ2ThnrLryvCxv2tad8XRDXA9zlcBQRg-U4'

# %%
def Complete_Dictionary(names, years, IDs):
    i = 0
    DIC = {}
    for ID in IDs:
        name = names[i]
        i += 1
        print('\n\nStation: '+ name)
        for year in years:
            print('Year: {}:'.format(year))
            A = AEMET_GET(year, year)
            js = A.connect(api_key, 'Data', ID)
            DIC[ID + str(year)] = A.get_DF(['indicativo', 'fecha', 'tm_mes', 'q_med', 'w_racha'], js)
    return DIC

# %%
DIC = Complete_Dictionary(names, years, IDs)
# Out:
# Station: BCN
# Year: 2012:
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 0076
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 9263D
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/00c41c02",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2013:
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 0076
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 9263D
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2a4a6aa9",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2014:
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 0076
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 9263D
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/8dce31e7",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2015:
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 0076
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 9263D
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b16ec3e6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2016:
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 0076
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 9263D
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/db39646a",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2017:
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 0076
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 9263D
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ec9c22ad",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2018:
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 0076
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 9263D
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/326048c0",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
#
#
# Station: PMP
# Year: 2012:
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 0076
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 9263D
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/e5b47f38",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2013:
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 0076
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 9263D
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/a96bc07e",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2014:
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 0076
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 9263D
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/9dd992a2",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2015:
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 0076
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 9263D
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c1fb0db3",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2016:
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 0076
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 9263D
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/ac23ab0b",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2017:
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 0076
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 9263D
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f74967b6",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2018:
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 0076
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 9263D
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/2cc58289",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
#
#
# Station: ZGZ
# Year: 2012:
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 0076
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 9263D
#
#  You are going to Download the data from 2012 to 2012
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/4d77dfbf",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2013:
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 0076
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 9263D
#
#  You are going to Download the data from 2013 to 2013
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/325cb6f4",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2014:
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 0076
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 9263D
#
#  You are going to Download the data from 2014 to 2014
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/f1badd97",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2015:
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 0076
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 9263D
#
#  You are going to Download the data from 2015 to 2015
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/c81e8b79",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2016:
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 0076
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 9263D
#
#  You are going to Download the data from 2016 to 2016
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/d38b5959",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2017:
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 0076
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 9263D
#
#  You are going to Download the data from 2017 to 2017
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5a0c6a66",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }
# Year: 2018:
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 0076
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 9263D
#
#  You are going to Download the data from 2018 to 2018
# from the station with ID 9434
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/5d87c52d",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"
# }

# %%
def concat_dictionary(DIC):
    keys_list = [key for key in DIC.keys()]
    for j in range(len(keys_list)):
        if j == 0:
            Final = DIC[keys_list[0]]
        else:
            Final = pd.concat([Final, DIC[keys_list[j]]])
    return Final

# %%
Data = concat_dictionary(DIC)

# %%
Final.to_csv('~/Rn_Weekly_NN/AEMET/Data/Monthly/BCN_ZGZ_PMP' + str(years[0]) + '-' + str(years[-1]) + '.csv')
