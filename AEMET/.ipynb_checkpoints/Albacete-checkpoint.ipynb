# %%
import numpy as np
import pandas as pd
import urllib
import json
import requests

# %%
df_ = []

año_inicial = int(input("Introducir año inicial: "))
año_final = int(input("Introducir año final: "))
IDEMA = input("introducir estacion: ")

INIT_YEAR = str(año_inicial)
END_YEAR = str(año_final)

print(año_inicial), print(año_final)
# Out:
# Introducir año inicial:  2016
# Introducir año final:  2016
# introducir estacion:  8178D
# 2016
# 2016
# (None, None)

# %%
range(año_inicial, año_final)
# Out:
# range(2016, 2016)

# %%
lista = list(range(año_inicial, año_final))
lista
# Out:
# []

# %%
for i in lista:
    api(i, i, idema, key)

# %%
for i in lista:
    for j in lista:
        if i != j:
            pass
        elif i == j:
            i

# %%
for i in lista:
    for j in lista:
        print(i == j)

# %% [markdown]
# ##

# %%
api_key='eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtLnJvZHJpZ3VlekBpbmRpemVuLmNvbSIsImp0aSI6IjI2NDM3ODU4LWM5NWQtNGM2Mi1iNDFmLWE5MzdhODJiYzc0ZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTY0MDM5NTYyLCJ1c2VySWQiOiIyNjQzNzg1OC1jOTVkLTRjNjItYjQxZi1hOTM3YTgyYmM3NGUiLCJyb2xlIjoiIn0.uK-NaBRTkJMapI9O7P8ovnD0ijmNuGNNtDaklqafJBo'

# %%
url = 'https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/%s/aniofin/%s/estacion/%s/?api_key=%s'%(INIT_YEAR, END_YEAR, IDEMA, api_key)
print(url)
# Out:
# https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/2016/aniofin/2016/estacion/8178D/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtLnJvZHJpZ3VlekBpbmRpemVuLmNvbSIsImp0aSI6IjI2NDM3ODU4LWM5NWQtNGM2Mi1iNDFmLWE5MzdhODJiYzc0ZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTY0MDM5NTYyLCJ1c2VySWQiOiIyNjQzNzg1OC1jOTVkLTRjNjItYjQxZi1hOTM3YTgyYmM3NGUiLCJyb2xlIjoiIn0.uK-NaBRTkJMapI9O7P8ovnD0ijmNuGNNtDaklqafJBo

# %%
#data = urllib.request.urlopen(url).read().decode()

# %%
api_json = urllib.request.urlopen(url).read().decode()
js = json.loads(api_json)

# %%
api_json
# Out:
# '{\n  "descripcion" : "exito",\n  "estado" : 200,\n  "datos" : "https://opendata.aemet.es/opendata/sh/553bdd8e",\n  "metadatos" : "https://opendata.aemet.es/opendata/sh/997c0034"\n}'

# %%
print(js)
print(js['datos'])
# Out:
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/553bdd8e', 'metadatos': 'https://opendata.aemet.es/opendata/sh/997c0034'}
# https://opendata.aemet.es/opendata/sh/553bdd8e

# %%
url_data = "https://opendata.aemet.es/opendata/sh/57c2a9e5"
url_metadata = "https://opendata.aemet.es/opendata/sh/997c0034"

# %%
api_data = urllib.request.urlopen(js['datos']).read().decode()

# %%
#metadata_ = urllib.request.urlopen(url_metadata).read().decode()

# %%
type(api_data)
# Out:
# str

# %%
js_2 = json.loads(api_data)

# %%
print(js_2)
# Out:
# [{'fecha': '2016-1', 'indicativo': '8178D', 'p_max': '4.5(05)', 'glo': '24947.0', 'hr': '74.0', 'n_gra': '0.0', 'n_fog': '5.0', 'q_max': '956.0(23)', 'nw_55': '3.0', 'q_mar': '1024.5', 'q_med': '944.5', 'tm_min': '4.0', 'ta_max': '19.9(24)', 'ts_min': '10.1', 'nt_30': '0.0', 'w_racha': '27/17.8(04)', 'np_100': '0.0', 'nw_91': '0.0', 'np_001': '10.0', 'ta_min': '-3.0(17)', 'w_rec': '160.0', 'e': '85.0', 'np_300': '0.0', 'p_mes': '17.6', 'n_llu': '11.0', 'n_tor': '0.0', 'w_med': '7.0', 'nt_00': '3.0', 'ti_max': '9.0', 'n_nie': '0.0', 'tm_mes': '8.9', 'tm_max': '13.6', 'q_min': '927.9(04)', 'np_010': '5.0'}, {'fecha': '2016-2', 'indicativo': '8178D', 'p_max': '4.3(06)', 'glo': '31704.0', 'hr': '67.0', 'n_gra': '0.0', 'n_fog': '1.0', 'q_max': '956.9(04)', 'nw_55': '9.0', 'q_mar': '1021.2', 'q_med': '941.4', 'tm_min': '3.6', 'ta_max': '19.0(02)', 'ts_min': '12.4', 'nt_30': '0.0', 'w_racha': '27/24.7(06)', 'np_100': '0.0', 'nw_91': '0.0', 'np_001': '10.0', 'ta_min': '-2.9(17)', 'w_rec': '2
# ...

# %%
api_df = pd.DataFrame(eval(api_data))

# %%
print(api_df.head())
# Out:
#        e   fecha      glo    hr indicativo n_fog n_gra n_llu n_nie n_tor  ...  \
# 0   85.0  2016-1  24947.0  74.0      8178D   5.0   0.0  11.0   0.0   0.0  ...
# 1   76.0  2016-2  31704.0  67.0      8178D   1.0   0.0  12.0   0.0   0.0  ...
# 2   71.0  2016-3  52396.0  61.0      8178D   0.0   0.0  11.0   0.0   0.0  ...
# 3   92.0  2016-4  60436.0  62.0      8178D   0.0   0.0  12.0   0.0   0.0  ...
# 4  105.0  2016-5  73738.0  56.0      8178D   0.0   0.0   9.0   0.0   2.0  ...
#
#      ta_max    ta_min ti_max tm_max tm_mes tm_min ts_min w_med      w_racha  \
# 0  19.9(24)  -3.0(17)    9.0   13.6    8.9    4.0   10.1   7.0  27/17.8(04)
# 1  19.0(02)  -2.9(17)    7.3   13.5    8.6    3.6   12.4  10.0  27/24.7(06)
# 2  26.9(30)  -1.1(12)    5.2   15.5    9.6    3.6    8.3   7.0  29/15.0(09)
# 3  24.0(26)   1.6(01)   11.8   19.1   13.2    7.3   11.8   6.0  99/15.0(12)
# 4  29.5(27)   2.9(02)   15.5   22.7   16.4   10.0   14.8   6.0  29/18.1(28)
#
#    w_rec
# 0  160.0
# 1  245.0
# ...

# %%
data_csv = api_df.to_csv(r'C:\Users\m.rodriguez\Desktop\PROJECT\data_csv.csv')

# %%
#data_csv.head()

# %%
api_df.filter(["e", "fecha", "glo", "indicativo", "ta_max", "ta_min", "tm_mes", "w_med"])
# Out:
#         e    fecha       glo indicativo        ta_max        ta_min tm_mes  \
# 0    85.0   2016-1   24947.0      8178D      19.9(24)      -3.0(17)    8.9
# 1    76.0   2016-2   31704.0      8178D      19.0(02)      -2.9(17)    8.6
# 2    71.0   2016-3   52396.0      8178D      26.9(30)      -1.1(12)    9.6
# 3    92.0   2016-4   60436.0      8178D      24.0(26)       1.6(01)   13.2
# 4   105.0   2016-5   73738.0      8178D      29.5(27)       2.9(02)   16.4
# 5   133.0   2016-6   85965.0      8178D      37.2(24)      10.6(01)   23.2
# 6   167.0   2016-7   84607.0      8178D      38.3(11)      14.9(17)   26.9
# 7   165.0   2016-8   75783.0      8178D      38.3(28)      14.5(13)   26.0
# 8   133.0   2016-9   60524.0      8178D      39.8(06)       9.8(19)   22.8
# 9   126.0  2016-10   40349.0      8178D      30.8(04)       4.5(31)   17.8
# 10   92.0  2016-11   26436.0      8178D      25.2(02)       0.1(16)   10.4
# ...

# %% [markdown]
# ## generando archivo de estaciones

# %%
url_estaciones = 'https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/?api_key=%s' %(api_key)
print(url_estaciones)
# Out:
# https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtLnJvZHJpZ3VlekBpbmRpemVuLmNvbSIsImp0aSI6IjI2NDM3ODU4LWM5NWQtNGM2Mi1iNDFmLWE5MzdhODJiYzc0ZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNTY0MDM5NTYyLCJ1c2VySWQiOiIyNjQzNzg1OC1jOTVkLTRjNjItYjQxZi1hOTM3YTgyYmM3NGUiLCJyb2xlIjoiIn0.uK-NaBRTkJMapI9O7P8ovnD0ijmNuGNNtDaklqafJBo

# %%
api_json_estaciones = urllib.request.urlopen(url_estaciones).read().decode()
js = json.loads(api_json_estaciones)  #el json de jsons

# %%
print(api_json_estaciones)
print(js['datos'])
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/6e48d417",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/0556af7a"
# }
# https://opendata.aemet.es/opendata/sh/6e48d417

# %%
url_datos_estaciones = 'https://opendata.aemet.es/opendata/sh/6e48d417'
url_metadata_estaciones = 'https://opendata.aemet.es/opendata/sh/0556af7a'

# %%
data_estaciones = urllib.request.urlopen(js['datos']).read().decode('latin-1')
js_estaciones = json.loads(data_estaciones)

# %%
data_estaciones
# Out:
# '[ {\n  "latitud" : "431825N",\n  "provincia" : "A CORUÑA",\n  "altitud" : "98",\n  "indicativo" : "1387E",\n  "nombre" : "A CORUÑA AEROPUERTO",\n  "indsinop" : "08002",\n  "longitud" : "082219W"\n}, {\n  "latitud" : "432157N",\n  "provincia" : "A CORUÑA",\n  "altitud" : "58",\n  "indicativo" : "1387",\n  "nombre" : "A CORUÑA",\n  "indsinop" : "08001",\n  "longitud" : "082517W"\n}, {\n  "latitud" : "430938N",\n  "provincia" : "A CORUÑA",\n  "altitud" : "50",\n  "indicativo" : "1393",\n  "nombre" : "CABO VILAN",\n  "indsinop" : "08006",\n  "longitud" : "091239W"\n}, {\n  "latitud" : "434710N",\n  "provincia" : "A CORUÑA",\n  "altitud" : "80",\n  "indicativo" : "1351",\n  "nombre" : "ESTACA DE BARES",\n  "indsinop" : "08004",\n  "longitud" : "074105W"\n}, {\n  "latitud" : "425529N",\n  "provincia" : "A CORUÑA",\n  "altitud" : "230",\n  "indicativo" : "1400",\n  "nombre" : "FISTERRA",\n  "indsinop" : "08040",\n  "longitud" : "091729W"\n}, {\n  "latitud" : "424314N",\n  "provincia" : "A 
# ...

# %%
js_estaciones
# Out:
# [{'latitud': '431825N',
#   'provincia': 'A CORUÑA',
#   'altitud': '98',
#   'indicativo': '1387E',
#   'nombre': 'A CORUÑA AEROPUERTO',
#   'indsinop': '08002',
#   'longitud': '082219W'},
#  {'latitud': '432157N',
#   'provincia': 'A CORUÑA',
#   'altitud': '58',
#   'indicativo': '1387',
#   'nombre': 'A CORUÑA',
#   'indsinop': '08001',
#   'longitud': '082517W'},
#  {'latitud': '430938N',
#   'provincia': 'A CORUÑA',
#   'altitud': '50',
#   'indicativo': '1393',
#   'nombre': 'CABO VILAN',
#   'indsinop': '08006',
#   'longitud': '091239W'},
#  {'latitud': '434710N',
#   'provincia': 'A CORUÑA',
#   'altitud': '80',
#   'indicativo': '1351',
#   'nombre': 'ESTACA DE BARES',
#   'indsinop': '08004',
#   'longitud': '074105W'},
#  {'latitud': '425529N',
#   'provincia': 'A CORUÑA',
#   'altitud': '230',
#   'indicativo': '1400',
#   'nombre': 'FISTERRA',
#   'indsinop': '08040',
#   'longitud': '091729W'},
#  {'latitud': '424314N',
#   'provincia': 'A CORUÑA',
# ...

# %%
estaciones_df = pd.DataFrame(eval(data_estaciones))
print(estaciones_df.columns)
estaciones_df.provincia.unique()
# Out:
# Index(['altitud', 'indicativo', 'indsinop', 'latitud', 'longitud', 'nombre',
#        'provincia'],
#       dtype='object')
# array(['A CORUÑA', 'ALBACETE', 'ALICANTE', 'ALMERIA', 'ARABA/ALAVA',
#        'ASTURIAS', 'AVILA', 'BADAJOZ', 'BARCELONA', 'BIZKAIA', 'BURGOS',
#        'CACERES', 'CADIZ', 'CANTABRIA', 'CASTELLON', 'CEUTA',
#        'CIUDAD REAL', 'CORDOBA', 'CUENCA', 'GIPUZKOA', 'GIRONA',
#        'GRANADA', 'GUADALAJARA', 'HUELVA', 'HUESCA', 'ILLES BALEARS',
#        'JAEN', 'LA RIOJA', 'LAS PALMAS', 'LEON', 'LLEIDA', 'LUGO',
#        'MADRID', 'MALAGA', 'MELILLA', 'MURCIA', 'NAVARRA', 'OURENSE',
#        'PALENCIA', 'PONTEVEDRA', 'SALAMANCA', 'SEGOVIA', 'SEVILLA',
#        'SORIA', 'STA. CRUZ DE TENERIFE', 'TARRAGONA', 'TERUEL', 'TOLEDO',
#        'VALENCIA', 'VALLADOLID', 'ZAMORA', 'ZARAGOZA'], dtype=object)

# %%
estaciones_df
# Out:
#     altitud indicativo indsinop  latitud longitud  \
# 0        98      1387E    08002  431825N  082219W
# 1        58       1387    08001  432157N  082517W
# 2        50       1393    08006  430938N  091239W
# 3        80       1351    08004  434710N  074105W
# 4       230       1400    08040  425529N  091729W
# 5       685      1437O    08043  424314N  085524W
# 6       100      1473A    08039  424418N  083738W
# 7       370       1428    08042  425317N  082438W
# 8       240      1475X    08041  425234N  083321W
# 9       702       8175    08280  385715N  015123W
# 10      676      8178D    08279  390020N  015144W
# 11      880      8177A    08278  385609N  013936W
# 12      646      7096B    08355  383231N  014211W
# 13       81       8025    08359  382221N  002939W
# 14       43       8019    08360  381658N  003415W
# 15       15      8050X    08370  384701N  001004E
# 16      575      7247X    08357  382359N  010217W
# 17      869      6302A    08427  370829N  024647W
# ...

# %%
estaciones_df[(estaciones_df.provincia=='ALBACETE') & (estaciones_df.indicativo=='8178D')]
# Out:
#    altitud indicativo indsinop  latitud longitud    nombre provincia
# 10     676      8178D    08279  390020N  015144W  ALBACETE  ALBACETE

# %%
lista_estaciones = estaciones_df['provincia']
lista_unique = lista_estaciones.unique()

# %%
estaciones_df.provincia.unique()
# Out:
# array(['A CORUÑA', 'ALBACETE', 'ALICANTE', 'ALMERIA', 'ARABA/ALAVA',
#        'ASTURIAS', 'AVILA', 'BADAJOZ', 'BARCELONA', 'BIZKAIA', 'BURGOS',
#        'CACERES', 'CADIZ', 'CANTABRIA', 'CASTELLON', 'CEUTA',
#        'CIUDAD REAL', 'CORDOBA', 'CUENCA', 'GIPUZKOA', 'GIRONA',
#        'GRANADA', 'GUADALAJARA', 'HUELVA', 'HUESCA', 'ILLES BALEARS',
#        'JAEN', 'LA RIOJA', 'LAS PALMAS', 'LEON', 'LLEIDA', 'LUGO',
#        'MADRID', 'MALAGA', 'MELILLA', 'MURCIA', 'NAVARRA', 'OURENSE',
#        'PALENCIA', 'PONTEVEDRA', 'SALAMANCA', 'SEGOVIA', 'SEVILLA',
#        'SORIA', 'STA. CRUZ DE TENERIFE', 'TARRAGONA', 'TERUEL', 'TOLEDO',
#        'VALENCIA', 'VALLADOLID', 'ZAMORA', 'ZARAGOZA'], dtype=object)

# %%
diccionario_prov = dict()
for provincia in lista_unique:
    diccionario_prov[provincia]=estaciones_df[estaciones_df.provincia == provincia]

# %%
diccionario_prov
# Out:
# {'A CORUÑA':   altitud indicativo indsinop  latitud longitud  \
#  0      98      1387E    08002  431825N  082219W
#  1      58       1387    08001  432157N  082517W
#  2      50       1393    08006  430938N  091239W
#  3      80       1351    08004  434710N  074105W
#  4     230       1400    08040  425529N  091729W
#  5     685      1437O    08043  424314N  085524W
#  6     100      1473A    08039  424418N  083738W
#  7     370       1428    08042  425317N  082438W
#  8     240      1475X    08041  425234N  083321W
#
#                                nombre provincia
#  0                A CORUÑA AEROPUERTO  A CORUÑA
#  1                           A CORUÑA  A CORUÑA
#  2                         CABO VILAN  A CORUÑA
#  3                    ESTACA DE BARES  A CORUÑA
#  4                           FISTERRA  A CORUÑA
#  5                       MONTE IROITE  A CORUÑA
#  6                             PADRÓN  A CORUÑA
#  7  SANTIAGO DE COMPOSTELA AEROPUERTO  A CORUÑA
# ...

# %%
print(diccionario_prov.keys())
# Out:
# dict_keys(['A CORUÑA', 'ALBACETE', 'ALICANTE', 'ALMERIA', 'ARABA/ALAVA', 'ASTURIAS', 'AVILA', 'BADAJOZ', 'BARCELONA', 'BIZKAIA', 'BURGOS', 'CACERES', 'CADIZ', 'CANTABRIA', 'CASTELLON', 'CEUTA', 'CIUDAD REAL', 'CORDOBA', 'CUENCA', 'GIPUZKOA', 'GIRONA', 'GRANADA', 'GUADALAJARA', 'HUELVA', 'HUESCA', 'ILLES BALEARS', 'JAEN', 'LA RIOJA', 'LAS PALMAS', 'LEON', 'LLEIDA', 'LUGO', 'MADRID', 'MALAGA', 'MELILLA', 'MURCIA', 'NAVARRA', 'OURENSE', 'PALENCIA', 'PONTEVEDRA', 'SALAMANCA', 'SEGOVIA', 'SEVILLA', 'SORIA', 'STA. CRUZ DE TENERIFE', 'TARRAGONA', 'TERUEL', 'TOLEDO', 'VALENCIA', 'VALLADOLID', 'ZAMORA', 'ZARAGOZA'])

# %%
type(diccionario_prov)
# Out:
# dict

# %%
type(diccionario_prov['ALBACETE'])
# Out:
# pandas.core.frame.DataFrame

# %%
diccionario_prov['ALBACETE']
# Out:
#    altitud indicativo indsinop  latitud longitud               nombre  \
# 9      702       8175    08280  385715N  015123W  ALBACETE BASE AÉREA
# 10     676      8178D    08279  390020N  015144W             ALBACETE
# 11     880      8177A    08278  385609N  013936W           CHINCHILLA
# 12     646      7096B    08355  383231N  014211W               HELLÍN
#
#    provincia
# 9   ALBACETE
# 10  ALBACETE
# 11  ALBACETE
# 12  ALBACETE

# %%
print(estaciones_df[estaciones_df.provincia=='ALBACETE'])
# Out:
#    altitud indicativo indsinop  latitud longitud               nombre  \
# 9      702       8175    08280  385715N  015123W  ALBACETE BASE AÉREA
# 10     676      8178D    08279  390020N  015144W             ALBACETE
# 11     880      8177A    08278  385609N  013936W           CHINCHILLA
# 12     646      7096B    08355  383231N  014211W               HELLÍN
#
#    provincia
# 9   ALBACETE
# 10  ALBACETE
# 11  ALBACETE
# 12  ALBACETE

# %%
for provincia in lista_unique:
    provincia = estaciones_df[estaciones_df.provincia == provincia]
    #csv_provincia = provincia.to_csv(r'C:\Users\m.rodriguez\Desktop\PROJECT\%s.csv')%(provincia)
    print(provincia)
# Out:
#   altitud indicativo indsinop  latitud longitud  \
# 0      98      1387E    08002  431825N  082219W
# 1      58       1387    08001  432157N  082517W
# 2      50       1393    08006  430938N  091239W
# 3      80       1351    08004  434710N  074105W
# 4     230       1400    08040  425529N  091729W
# 5     685      1437O    08043  424314N  085524W
# 6     100      1473A    08039  424418N  083738W
# 7     370       1428    08042  425317N  082438W
# 8     240      1475X    08041  425234N  083321W
#
#                               nombre provincia
# 0                A CORUÑA AEROPUERTO  A CORUÑA
# 1                           A CORUÑA  A CORUÑA
# 2                         CABO VILAN  A CORUÑA
# 3                    ESTACA DE BARES  A CORUÑA
# 4                           FISTERRA  A CORUÑA
# 5                       MONTE IROITE  A CORUÑA
# 6                             PADRÓN  A CORUÑA
# 7  SANTIAGO DE COMPOSTELA AEROPUERTO  A CORUÑA
# 8             SANTIAGO DE COMPOSTELA  A CORUÑA
# ...

# %%
provincia ='ALBACETE'
nombre ='ALBACETE'
empty_str = ''

# %%
def funcion (param1, param2):
    if param1 in provincia and param2 in nombre:
        a = estaciones_df[(estaciones_df.provincia==provincia) & (estaciones_df.nombre==nombre)]
        return a  #el df a devuelve la información de un estacion concreta para una provincia dada.
    elif param1 in provincia and not param2:
        b = estaciones_df[(estaciones_df.provincia==provincia)]
        return b  #el df b devuelve la información de las estaciones de una provincia dada.

# %%
def funcion2 (param1, param2):
    if param1 in a:
        idema_a = a[a.nombre==nombre].indicativo.item()
        return idema_a
    else:
        idema_b = b.indicativo.item()
        return idema_b

# %%
a = estaciones_df[(estaciones_df.provincia==provincia) & (estaciones_df.nombre == nombre)]
a
# Out:
#    altitud indicativo indsinop  latitud longitud    nombre provincia
# 10     676      8178D    08279  390020N  015144W  ALBACETE  ALBACETE

# %%
b = estaciones_df[(estaciones_df.provincia==provincia)]
b
# Out:
#    altitud indicativo indsinop  latitud longitud               nombre  \
# 9      702       8175    08280  385715N  015123W  ALBACETE BASE AÉREA
# 10     676      8178D    08279  390020N  015144W             ALBACETE
# 11     880      8177A    08278  385609N  013936W           CHINCHILLA
# 12     646      7096B    08355  383231N  014211W               HELLÍN
#
#    provincia
# 9   ALBACETE
# 10  ALBACETE
# 11  ALBACETE
# 12  ALBACETE

# %%
b[['indicativo', 'nombre']]
# Out:
#    indicativo               nombre
# 9        8175  ALBACETE BASE AÉREA
# 10      8178D             ALBACETE
# 11      8177A           CHINCHILLA
# 12      7096B               HELLÍN

# %%
b[b.nombre==nombre].indicativo.item()
# Out:
# '8178D'

# %%
a.indicativo.item()
# Out:
# '8178D'
